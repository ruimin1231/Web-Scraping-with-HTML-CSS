# %%
import sys
#sys.path.append('my/path/to/module/folder')
sys.path.append('/Users/ruiminma/.pyenv/versions/3.6.1/lib/python3.6/site-packages')

# %%
#import Splinter and Beautifulsoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
#set up Splinter
executable_path = {'executable_path':ChromeDriverManager().install()}
browser = Browser('chrome',**executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/ruiminma/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache

# %%
#Visit the Quotes to Scrape site
url = 'http://books.toscrape.com/'
browser.visit(url)

# %%
#Parse the HTML
html = browser.html
html_soup = soup(html,'html.parser')

# %%
#Scrape the title
title = html_soup.find_all('strong')[5].text
title
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/9q/g7z0jmnx4q11sb59s6vvk1zw0000gn/T/ipykernel_2517/2701557576.py in <module>
#       1 #Scrape the title
# ----> 2 title = html_soup.find_all('strong')[5].text
#       3 title
#
# IndexError: list index out of range

# %%
title = html_soup.find('li', class_='active').text
title

class="nav nav-list"
# Out:
# 'All products'

# %%
#Scrape the books categories
side_category = html_soup.find('div',class_='side-categories')

#side-categories
categories = side_category.find_all('a', href='index.html')
for category in indexes:
    word = index.text
    print(word)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9q/g7z0jmnx4q11sb59s6vvk1zw0000gn/T/ipykernel_2517/2648529863.py in <module>
#       3
#       4 #side-categories
# ----> 5 categories = side_category.find_all('a', href='index.html')
#       6 for category in indexes:
#       7     word = index.text
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
side_category = html_soup.find('div',class_='side-categories')
side_category

# %%
nav_list = html_soup.find ('ul',class_='nav nav-list')
nav_list
# Out:
# <ul class="nav nav-list">
# <li>
# <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>
# <ul>
# <li>
# <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>
# </li>
# <li>
# ...

# %%
nav_list = html_soup.find ('ul',class_='nav nav-list')

nav_lists = nav_list.find_all ('a',href_='index.html')

# %%
#Scrape the top ten tags
t1 = html_soup.find('ul',class_='nav nav-list')
# print(t1)

t2 = t1.find('li')

t3 = t2.find('ul')

t4 = t3.find_all('li')


for t in t4:
    t5 = t.find('a')
    print(t5.text)



# #tag_box
# tags = tag_box.find_all('a', class_='tag')
# for tag in tags:
#     word = tag.text
#     print(word)
# Out:
#
#                                 Travel
#
#
#
#
#                                 Mystery
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#                                 Sequential Art
#
#
#
#
#                                 Classics
#
#
#
#
#                                 Philosophy
#
#
#
#
#                                 Romance
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#                                 Fiction
#
#
#
#
#                                 Childrens
#
#
#
#
#                                 Religion
#
#
#
#
#                                 Nonfiction
#
#
#
#
#                                 Music
#
#
#
#
#                                 Default
#
#
#
#
#                                 Science Fiction
#
#
#
#
#                                 Sports and Games
#
#
#
#
#                                 Add a comment
#
#
#
#
#                                 Fantasy
#
#
#
#
# ...
